# %% [markdown]
# <a href="https://colab.research.google.com/github/Subedi-sabina/Customer_Churn_Project/blob/main/Using_ANN_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# Replace 'path/to/your/file.csv' with the actual path to your file in Google Drive
file_path = '/content/drive/MyDrive/customer_churn_telecom 1.csv'

# Read the CSV file into a Pandas DataFrame
df = pd.read_csv(file_path)

# Display the first few rows of the DataFrame
print(df.head())
# Out:
#    CustomerID  Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0           1   22  Female      25               14              4
# 1           2   41  Female      28               28              7
# 2           3   47    Male      27               10              2
# 3           4   35    Male       9               12              5
# 4           5   53  Female      58               24              9
#
#    Payment Delay Subscription Type Contract Length  Total Spend  \
# 0             27             Basic         Monthly          598
# 1             13          Standard         Monthly          584
# 2             29           Premium          Annual          757
# 3             17           Premium       Quarterly          232
# 4              2          Standard          Annual          533
#
#    Last Interaction  Churn
# 0                 9      1
# 1                20      0
# 2                21      0
# 3                18      0
# 4                18      0

# %%
df.head(10)
# Out:
#    CustomerID  Age  Gender  Tenure  Usage Frequency  Support Calls  \
# 0           1   22  Female      25               14              4
# 1           2   41  Female      28               28              7
# 2           3   47    Male      27               10              2
# 3           4   35    Male       9               12              5
# 4           5   53  Female      58               24              9
# 5           6   30    Male      41               14             10
# 6           7   47  Female      37               15              9
# 7           8   54  Female      36               11              0
# 8           9   36    Male      20                5             10
# 9          10   65    Male       8                4              2
#
#    Payment Delay Subscription Type Contract Length  Total Spend  \
# 0             27             Basic         Monthly          598
# 1             13          Standard         Monthly          584
# 2             29           Premium          Annual          757
# 3             17           Premium       Quarterly          232
# 4              2          Standard          Annual          533
# 5             10           Premium         Monthly          500
# 6             28             Basic       Quarterly          574
# 7             18          Standard         Monthly          323
# 8              8             Basic         Monthly          687
# 9             23             Basic          Annual          995
#
#    Last Interaction  Churn
# 0                 9      1
# 1                20      0
# 2                21      0
# 3                18      0
# 4                18      0
# 5                29      0
# 6                14      1
# 7                16      0
# 8                 8      0
# 9                10      0

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
# Import necessary libraries
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

# %%
# Remove unnecessary columns
df = df.drop(columns=['CustomerID'])

# %%
# Define categorical and numerical columns
categorical_cols = ['Gender']
ordinal_col = ['Subscription Type','Contract Length']
numerical_cols = ['Age','Tenure', 'Usage Frequency', 'Support Calls',
       'Payment Delay', 'Total Spend',
       'Last Interaction']

# %%
# Apply Ordinal Encoding for 'Card Type'
ordinal_encoder = OrdinalEncoder(categories=[['Basic','Standard','Premium'],['Monthly', 'Quarterly','Annual']])
df[ordinal_col] = ordinal_encoder.fit_transform(df[ordinal_col])

# %%
# Apply One-Hot Encoding for 'Geography' and 'Gender'
one_hot_encoder = OneHotEncoder(drop='first', sparse=False)
encoded_categorical = pd.DataFrame(one_hot_encoder.fit_transform(df[categorical_cols]), columns=one_hot_encoder.get_feature_names_out(categorical_cols))
df = df.drop(columns=categorical_cols)
df = pd.concat([df, encoded_categorical], axis=1)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
df.head(10)
# Out:
#    Age  Tenure  Usage Frequency  Support Calls  Payment Delay  \
# 0   22      25               14              4             27
# 1   41      28               28              7             13
# 2   47      27               10              2             29
# 3   35       9               12              5             17
# 4   53      58               24              9              2
# 5   30      41               14             10             10
# 6   47      37               15              9             28
# 7   54      36               11              0             18
# 8   36      20                5             10              8
# 9   65       8                4              2             23
#
#    Subscription Type  Contract Length  Total Spend  Last Interaction  Churn  \
# 0                0.0              0.0          598                 9      1
# 1                1.0              0.0          584                20      0
# 2                2.0              2.0          757                21      0
# 3                2.0              1.0          232                18      0
# 4                1.0              2.0          533                18      0
# 5                2.0              0.0          500                29      0
# 6                0.0              1.0          574                14      1
# 7                1.0              0.0          323                16      0
# 8                0.0              0.0          687                 8      0
# 9                0.0              2.0          995                10      0
#
#    Gender_Male
# 0          0.0
# 1          0.0
# 2          1.0
# 3          1.0
# 4          0.0
# 5          1.0
# 6          0.0
# 7          0.0
# 8          1.0
# 9          1.0

# %%
# Scale numerical features
scaler = StandardScaler()
df[numerical_cols] = scaler.fit_transform(df[numerical_cols])

# %%
df
# Out:
#             Age    Tenure  Usage Frequency  Support Calls  Payment Delay  \
# 0     -1.434202 -0.409100        -0.122526      -0.449807       1.114538
# 1     -0.069730 -0.233642         1.465424       0.513590      -0.467000
# 2      0.361155 -0.292128        -0.576225      -1.092072       1.340472
# 3     -0.500616 -1.344876        -0.349375      -0.128674      -0.015132
# 4      0.792041  1.520939         1.011724       1.155855      -1.709637
# ...         ...       ...              ...            ...            ...
# 64369  0.217527  0.058789        -0.349375       0.192458       0.436736
# 64370 -0.356988 -1.520334        -1.597050      -0.128674       0.549703
# 64371 -1.218759  0.409705        -0.122526       0.834723       1.453439
# 64372  0.576598 -0.818502         0.444599       0.513590       0.549703
# 64373  0.720227  0.760621        -0.009101       1.155855       0.888604
#
#        Subscription Type  Contract Length  Total Spend  Last Interaction  \
# 0                    0.0              0.0     0.218408         -0.752324
# 1                    1.0              0.0     0.164742          0.521065
# 2                    2.0              2.0     0.827900          0.636827
# 3                    2.0              1.0    -1.184575          0.289540
# 4                    1.0              2.0    -0.030756          0.289540
# ...                  ...              ...          ...               ...
# 64369                0.0              1.0     1.556225         -0.173511
# 64370                1.0              2.0     1.464226         -0.752324
# 64371                2.0              0.0    -0.820413          0.521065
# 64372                1.0              0.0    -0.003923         -0.289273
# 64373                1.0              0.0     0.594070          0.752590
#
#        Churn  Gender_Male
# 0          1          0.0
# 1          0          0.0
# 2          0          1.0
# 3          0          1.0
# 4          0          0.0
# ...      ...          ...
# 64369      1          0.0
# 64370      1          1.0
# 64371      1          1.0
# 64372      1          0.0
# 64373      1          0.0
#
# [64374 rows x 11 columns]

# %%
###Step 3:Model Building  Logistics Regression
# Define features (X) and target (y)
X = df.drop(columns=['Churn'])
y = df['Churn']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
 ##Building the ANN model
model = Sequential()
model.add(Dense(units=12, activation='relu', input_dim=X_train.shape[1]))
model.add(Dense(units=8, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))

# Compiling the ANN
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Training the ANN
model.fit(X_train, y_train, batch_size=5, epochs=20, validation_split=0.3)
# Out:
# Epoch 1/20
# 6309/6309 [==============================] - 22s 3ms/step - loss: 0.3422 - accuracy: 0.8467 - val_loss: 0.2438 - val_accuracy: 0.8946
# Epoch 2/20
# 6309/6309 [==============================] - 17s 3ms/step - loss: 0.2209 - accuracy: 0.9036 - val_loss: 0.1883 - val_accuracy: 0.9219
# Epoch 3/20
# 6309/6309 [==============================] - 16s 3ms/step - loss: 0.1826 - accuracy: 0.9218 - val_loss: 0.1606 - val_accuracy: 0.9311
# Epoch 4/20
# 6309/6309 [==============================] - 18s 3ms/step - loss: 0.1597 - accuracy: 0.9329 - val_loss: 0.1440 - val_accuracy: 0.9407
# Epoch 5/20
# 6309/6309 [==============================] - 18s 3ms/step - loss: 0.1448 - accuracy: 0.9403 - val_loss: 0.1326 - val_accuracy: 0.9436
# Epoch 6/20
# 6309/6309 [==============================] - 16s 3ms/step - loss: 0.1308 - accuracy: 0.9459 - val_loss: 0.1146 - val_accuracy: 0.9507
# Epoch 7/20
# 6309/6309 [==============================] - 18s 3ms/step - loss: 0.1177 - accuracy: 0.9511 - val_loss: 0.1016 - val_accuracy: 0.9599
# Epoch 8/20
# 6309/6309 [==============================] - 17s 3ms/step - loss: 0.1088 - accuracy: 0.9558 - val_loss: 0.0945 - val_accuracy: 0.9618
# Epoch 9/20
# 6309/6309 [==============================] - 16s 3ms/step - loss: 0.0993 - accuracy: 0.9602 - val_loss: 0.0841 - val_accuracy: 0.9663
# Epoch 10/20
# 6309/6309 [==============================] - 16s 2ms/step - loss: 0.0909 - accuracy: 0.9621 - val_loss: 0.0786 - val_accuracy: 0.9692
# Epoch 11/20
# 6309/6309 [==============================] - 18s 3ms/step - loss: 0.0835 - accuracy: 0.9661 - val_loss: 0.0735 - val_accuracy: 0.9689
# Epoch 12/20
# 6309/6309 [==============================] - 16s 3ms/step - loss: 0.0780 - accuracy: 0.9684 - val_loss: 0.0671 - val_accuracy: 0.9719
# Epoch 13/20
# 6309/6309 [==============================] - 18s 3ms/step - loss: 0.0734 - accuracy: 0.9692 - val_loss: 0.0644 - val_accuracy: 0.9747
# Epoch 14/20
# 6309/6309 [==============================] - 17s 3ms/step - loss: 0.0688 - accuracy: 0.9716 - val_loss: 0.0659 - val_accuracy: 0.9711
# Epoch 15/20
# 6309/6309 [==============================] - 16s 2ms/step - loss: 0.0664 - accuracy: 0.9722 - val_loss: 0.0574 - val_accuracy: 0.9782
# Epoch 16/20
# 6309/6309 [==============================] - 17s 3ms/step - loss: 0.0630 - accuracy: 0.9744 - val_loss: 0.0635 - val_accuracy: 0.9729
# Epoch 17/20
# 6309/6309 [==============================] - 16s 3ms/step - loss: 0.0601 - accuracy: 0.9758 - val_loss: 0.0586 - val_accuracy: 0.9750
# Epoch 18/20
# 6309/6309 [==============================] - 16s 2ms/step - loss: 0.0580 - accuracy: 0.9763 - val_loss: 0.0498 - val_accuracy: 0.9795
# Epoch 19/20
# 6309/6309 [==============================] - 15s 2ms/step - loss: 0.0557 - accuracy: 0.9776 - val_loss: 0.0542 - val_accuracy: 0.9770
# Epoch 20/20
# 6309/6309 [==============================] - 18s 3ms/step - loss: 0.0538 - accuracy: 0.9783 - val_loss: 0.0490 - val_accuracy: 0.9798

# %%
# Evaluating the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test Accuracy: {accuracy:.2f}')

# Making predictions
y_pred = (model.predict(X_test) > 0.5).astype("int32")

# Displaying the results
y_pred
# Out:
# 604/604 [==============================] - 1s 2ms/step - loss: 0.0511 - accuracy: 0.9788
# Test Accuracy: 0.98
# 604/604 [==============================] - 1s 1ms/step
# array([[0],
#        [0],
#        [1],
#        ...,
#        [0],
#        [1],
#        [1]], dtype=int32)

# %%
# Print the classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98     10134
#            1       0.98      0.97      0.98      9179
#
#     accuracy                           0.98     19313
#    macro avg       0.98      0.98      0.98     19313
# weighted avg       0.98      0.98      0.98     19313
